# %% [markdown]
# # *Asignatura:Análisis de Señales y Sistemas de Comunicación*
# #### *Nombre del alumn@:*
# Barrera Sanchez Lilian Mayrin
# Fecha de entrega:16/06/2023
# # Temario:
# 2.Analisis de señales periodicas en el tiempo: series de Fourier.
# 2.1 Representación de señales periodicas por series de Fourier trigonometricas.
# 2.2 Series de Fourier exponenciales.
# 2.3 Vista alternativa de la presentación de Fourier: analisis señal-vector.

# %% [markdown]
# ### Desarrollar en serie de Fourier la función periodica de periodo 2π. Representar graficamente y estudiar la convergencia de la serie en $\mathbb{R}$
# $f(x) = \begin{cases}
#       0 & \text{si } -π \leq x \leq 0 \\
#       x & \text{si } 0 \leq x \leq π  \\
#    \end{cases}
# $

# %% [markdown]
# # *Trasnformada de fourier rapida, discreta Graficar sonido, audio, representacion armonicos 10, 80, 160, 250, 500*

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((0, x < 0), (x, x >= 0))

# Calcular los coeficientes de Fourier para los primeros 10 armónicos
T = 2
armonicos = 10
a0 = sp.integrate(f, (x, -1, 1)) / T
an = [(2 / T) * sp.integrate(f * sp.cos(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-1, 1, 1000)
f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (10 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((0, x < 0), (x, x >= 0))

# Calcular los coeficientes de Fourier para los primeros 80 armónicos
T = 2
armonicos = 80
a0 = sp.integrate(f, (x, -1, 1)) / T
an = [(2 / T) * sp.integrate(f * sp.cos(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-1, 1, 1000)
f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (80 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((0, x < 0), (x, x >= 0))

# Calcular los coeficientes de Fourier para los primeros 160 armónicos
T = 2
armonicos = 160
a0 = sp.integrate(f, (x, -1, 1)) / T
an = [(2 / T) * sp.integrate(f * sp.cos(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-1, 1, 1000)
f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (160 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((0, x < 0), (x, x >= 0))

# Calcular los coeficientes de Fourier para los primeros 10 armónicos
T = 2
armonicos = 250
a0 = sp.integrate(f, (x, -1, 1)) / T
an = [(2 / T) * sp.integrate(f * sp.cos(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-1, 1, 1000)
f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (250 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 22
#      20 x_vals = np.linspace(-1, 1, 1000)
#      21 f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
# ---> 22 fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
#      23                            for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])
#      25 plt.plot(x_vals, f_vals, label='Función original')
#      26 plt.plot(x_vals, fourier_vals, label='Serie de Fourier (250 armónicos)')
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/decorators.py:106, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     104         if f is not None:
#     105             return f(self)
# --> 106 return func(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/expr.py:198, in Expr.__add__(self, other)
#     195 @sympify_return([('other', 'Expr')], NotImplemented)
#     196 @call_highest_priority('__radd__')
#     197 def __add__(self, other):
# --> 198     return Add(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/add.py:338, in Add.flatten(cls, seq)
#     335             newseq.append(Mul(c, s, evaluate=False))
#     336         else:
#     337             # alternatively we have to call all Mul's machinery (slow)
# --> 338             newseq.append(Mul(c, s))
#     340     noncommutative = noncommutative or not s.is_commutative
#     342 # oo, -oo
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/mul.py:482, in Mul.flatten(cls, seq)
#     479     return new_c_powers
#     481 # in c_powers
# --> 482 c_powers = _gather(c_powers)
#     484 # and in num_exp
#     485 num_exp = _gather(num_exp)
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/mul.py:471, in Mul.flatten.<locals>._gather(c_powers)
#     469 for b, e in c_powers:
#     470     co = e.as_coeff_Mul()
# --> 471     common_b.setdefault(b, {}).setdefault(
#     472         co[1], []).append(co[0])
#     473 for b, d in common_b.items():
#     474     for di, li in d.items():
#
# File /opt/conda/lib/python3.10/site-packages/sympy/core/numbers.py:3875, in NumberSymbol.__hash__(self)
#    3874 def __hash__(self):
# -> 3875     return super().__hash__()
#
# KeyboardInterrupt:

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((0, x < 0), (x, x >= 0))

# Calcular los coeficientes de Fourier para los primeros 10 armónicos
T = 2
armonicos = 500
a0 = sp.integrate(f, (x, -1, 1)) / T
an = [(2 / T) * sp.integrate(f * sp.cos(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(sp.pi * n * x), (x, -1, 1)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-1, 1, 1000)
f_vals = np.piecewise(x_vals, [x_vals < 0, x_vals >= 0], [0, lambda x: x])
fourier_vals = a0/2 + sum([an_val * np.cos(n * np.pi * x_vals) + bn_val * np.sin(n * np.pi * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (500 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Desarrollar en serie de Fourier la función periódica de período 2π, definida por:
# $f(x)=χ², -π \leq x \leq π $

# %% [markdown]
# # *Trasnformada de fourier rapida, discreta Graficar sonido, audio, representacion armonicos 10, 80, 160, 250, 500*

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((x**2, sp.And(x >= -sp.pi, x <= sp.pi)), (0, True))

# Calcular los coeficientes de Fourier para los primeros 10 armónicos
T = 2*sp.pi
armonicos = 10
a0 = (1 / T) * sp.integrate(f, (x, -sp.pi, sp.pi))
an = [(2 / T) * sp.integrate(f * sp.cos(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-np.pi, np.pi, 1000)
f_vals = np.piecewise(x_vals, [np.logical_and(x_vals >= -np.pi, x_vals <= np.pi)], [lambda x: x**2, 0])
fourier_vals = a0/2 + sum([an_val * np.cos(n * x_vals) + bn_val * np.sin(n * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (10 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((x**2, sp.And(x >= -sp.pi, x <= sp.pi)), (0, True))

# Calcular los coeficientes de Fourier para los primeros 10 armónicos
T = 2*sp.pi
armonicos = 80
a0 = (1 / T) * sp.integrate(f, (x, -sp.pi, sp.pi))
an = [(2 / T) * sp.integrate(f * sp.cos(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-np.pi, np.pi, 1000)
f_vals = np.piecewise(x_vals, [np.logical_and(x_vals >= -np.pi, x_vals <= np.pi)], [lambda x: x**2, 0])
fourier_vals = a0/2 + sum([an_val * np.cos(n * x_vals) + bn_val * np.sin(n * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (80 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((x**2, sp.And(x >= -sp.pi, x <= sp.pi)), (0, True))

# Calcular los coeficientes de Fourier para los primeros 160 armónicos
T = 2*sp.pi
armonicos = 160
a0 = (1 / T) * sp.integrate(f, (x, -sp.pi, sp.pi))
an = [(2 / T) * sp.integrate(f * sp.cos(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-np.pi, np.pi, 1000)
f_vals = np.piecewise(x_vals, [np.logical_and(x_vals >= -np.pi, x_vals <= np.pi)], [lambda x: x**2, 0])
fourier_vals = a0/2 + sum([an_val * np.cos(n * x_vals) + bn_val * np.sin(n * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (160 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((x**2, sp.And(x >= -sp.pi, x <= sp.pi)), (0, True))

# Calcular los coeficientes de Fourier para los primeros 250 armónicos
T = 2*sp.pi
armonicos = 250
a0 = (1 / T) * sp.integrate(f, (x, -sp.pi, sp.pi))
an = [(2 / T) * sp.integrate(f * sp.cos(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-np.pi, np.pi, 1000)
f_vals = np.piecewise(x_vals, [np.logical_and(x_vals >= -np.pi, x_vals <= np.pi)], [lambda x: x**2, 0])
fourier_vals = a0/2 + sum([an_val * np.cos(n * x_vals) + bn_val * np.sin(n * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (250 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

x = sp.Symbol('x')
n = sp.Symbol('n', integer=True)

# Definir la función periódica f(x)
f = sp.Piecewise((x**2, sp.And(x >= -sp.pi, x <= sp.pi)), (0, True))

# Calcular los coeficientes de Fourier para los primeros 500 armónicos
T = 2*sp.pi
armonicos = 500
a0 = (1 / T) * sp.integrate(f, (x, -sp.pi, sp.pi))
an = [(2 / T) * sp.integrate(f * sp.cos(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]
bn = [(2 / T) * sp.integrate(f * sp.sin(n * x), (x, -sp.pi, sp.pi)) for n in range(1, armonicos + 1)]


# Representación gráfica de la serie de Fourier
x_vals = np.linspace(-np.pi, np.pi, 1000)
f_vals = np.piecewise(x_vals, [np.logical_and(x_vals >= -np.pi, x_vals <= np.pi)], [lambda x: x**2, 0])
fourier_vals = a0/2 + sum([an_val * np.cos(n * x_vals) + bn_val * np.sin(n * x_vals)
                           for an_val, bn_val, n in zip(an, bn, range(1, armonicos + 1))])

plt.plot(x_vals, f_vals, label='Función original')
plt.plot(x_vals, fourier_vals, label='Serie de Fourier (500 armónicos)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()
